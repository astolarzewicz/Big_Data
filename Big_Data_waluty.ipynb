# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd

# ------- Dolar --------
USD = requests.get("https://api.nbp.pl/api/exchangerates/rates/a/usd/2020-01-01/2020-07-18/")
usd_frame = pd.read_json(USD.content)
usd_rates = usd_frame.rates
usd_list=[index['mid'] for index in usd_rates]

USD19 = requests.get("https://api.nbp.pl/api/exchangerates/rates/a/usd/2019-01-01/2019-07-18/")
usd19_frame = pd.read_json(USD19.content)
usd19_rates = usd19_frame.rates
usd19_list=[index['mid'] for index in usd19_rates]

plt.plot(usd_list, '-g', usd19_list, '-b')
plt.xticks(rotation = 45)
plt.title("Kurs dolara w analogicznych okresach 2019 i 2020 r.")
plt.xlabel("Liczba dni od rozpoczęcia roku")
plt.ylabel("Cena [PLN]")
plt.legend(["USD 2020", "USD 2019"])
plt.grid()

plt.show()

# %%
# ------- Funt brytyjski --------
GBP = requests.get("https://api.nbp.pl/api/exchangerates/rates/a/gbp/2020-01-01/2020-07-18/")
gbp_frame = pd.read_json(GBP.content)
gbp_rates = gbp_frame.rates
gbp_list=[index['mid'] for index in gbp_rates]

GBP19 = requests.get("https://api.nbp.pl/api/exchangerates/rates/a/gbp/2019-01-01/2019-07-18/")
gbp19_frame = pd.read_json(GBP19.content)
gbp19_rates = gbp19_frame.rates
gbp19_list=[index['mid'] for index in gbp19_rates]

plt.plot(gbp_list, '-g', gbp19_list, '-b')
plt.xticks(rotation=45)
plt.title("Kurs funta brytyjskiego w analogicznych okresach 2019 i 2020 r.")
plt.xlabel("Liczba dni od rozpoczęcia roku")
plt.ylabel("Cena [PLN]")
plt.legend(["GBP 2020", "GBP 2019"])
plt.grid()

plt.show()

# %%
# ------- Euro --------
EUR = requests.get("https://api.nbp.pl/api/exchangerates/rates/a/eur/2020-01-01/2020-07-18/")
eur_frame = pd.read_json(EUR.content)
eur_rates = eur_frame.rates
eur_list=[index['mid'] for index in eur_rates]

EUR19 = requests.get("https://api.nbp.pl/api/exchangerates/rates/a/eur/2019-01-01/2019-07-18/")
eur19_frame = pd.read_json(EUR19.content)
eur19_rates = eur19_frame.rates
eur19_list=[index['mid'] for index in eur19_rates]

plt.plot(eur_list, '-g', eur19_list, '-b')
plt.xticks(rotation=45)
plt.title("Kurs euro w analogicznych okresach 2019 i 2020 r.")
plt.xlabel("Liczba dni od rozpoczęcia roku")
plt.ylabel("Cena [PLN]")
plt.legend(["EUR 2020", "EUR 2019"])
plt.grid()

plt.show()

# %%
# ------- Jen --------
JPY = requests.get("https://api.nbp.pl/api/exchangerates/rates/a/jpy/2020-01-01/2020-07-18/")
jpy_frame = pd.read_json(JPY.content)
jpy_rates = jpy_frame.rates
jpy_list=[index['mid'] for index in jpy_rates]

JPY19 = requests.get("https://api.nbp.pl/api/exchangerates/rates/a/jpy/2019-01-01/2019-07-18/")
jpy19_frame = pd.read_json(JPY19.content)
jpy19_rates = jpy19_frame.rates
jpy19_list=[index['mid'] for index in jpy19_rates]

plt.plot(jpy_list, '-g', jpy19_list, '-b')
plt.xticks(rotation=45)
plt.title("Kurs jena w analogicznych okresach 2019 i 2020 r.")
plt.xlabel("Liczba dni od rozpoczęcia roku")
plt.ylabel("Cena [PLN]")
plt.legend(["JPY 2020", "JPY 2019"])
plt.grid()

plt.show()

# %%
# ------- Frank szwajcarski --------
CHF = requests.get("https://api.nbp.pl/api/exchangerates/rates/a/chf/2020-01-01/2020-07-18/")
chf_frame = pd.read_json(CHF.content)
chf_rates = chf_frame.rates
chf_list=[index['mid'] for index in chf_rates]

CHF19 = requests.get("https://api.nbp.pl/api/exchangerates/rates/a/chf/2019-01-01/2019-07-18/")
chf19_frame = pd.read_json(CHF19.content)
chf19_rates = chf19_frame.rates
chf19_list=[index['mid'] for index in chf19_rates]

plt.plot(chf_list, '-g', chf19_list, '-b')
plt.xticks(rotation=45)
plt.title("Kurs franka szwajcarskiego w analogicznych okresach 2019 i 2020 r.")
plt.xlabel("Liczba dni od rozpoczęcia roku")
plt.ylabel("Cena [PLN]")
plt.legend(["CHF 2020", "CHF 2019"])
plt.grid()

plt.show()

# %%
# ------- Korona norweska --------
NOK = requests.get("https://api.nbp.pl/api/exchangerates/rates/a/nok/2020-01-01/2020-07-18/")
nok_frame = pd.read_json(NOK.content)
nok_rates = nok_frame.rates
nok_list=[index['mid'] for index in nok_rates]

NOK19 = requests.get("https://api.nbp.pl/api/exchangerates/rates/a/nok/2019-01-01/2019-07-18/")
nok19_frame = pd.read_json(NOK19.content)
nok19_rates = nok19_frame.rates
nok19_list=[index['mid'] for index in nok19_rates]

plt.plot(nok_list, '-g', nok19_list, '-b')
plt.xticks(rotation=45)
plt.title("Kurs korony norweskiej w analogicznych okresach 2019 i 2020 r.")
plt.xlabel("Liczba dni od rozpoczęcia roku")
plt.ylabel("Cena [PLN]")
plt.legend(["NOK 2020", "NOK 2019"])
plt.grid()

plt.show()
